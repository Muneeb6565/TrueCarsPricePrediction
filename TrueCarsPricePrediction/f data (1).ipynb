# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#dataset1
df_1 = pd.read_csv("true_car_listings.csv")

# %%
df_2 = pd.read_csv('tc20171021.csv', usecols = [i for i in range(1,9)])

# %%
df = pd.concat([df_1, df_2])
df.index = pd.RangeIndex(len(df.index))
df.index = range(len(df.index))

# %%
df
# Out:
#          Price  Year  Mileage              City State                Vin  \
# 0         8995  2014    35725           El Paso    TX  19VDE2E53EE000083
# 1        10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 2         8995  2013    48851           El Paso    TX  19VDE2E52DE000025
# 3        10999  2014    39922           Windsor    CO  19VDE1F71EE003817
# 4        14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# ...        ...   ...      ...               ...   ...                ...
# 2085159  79900  2017       25      East Hanover    NJ  YV4BC0ZX0H1128239
# 2085160  80895  2017       10      Corte Madera    CA  YV4BC0ZX0H1124188
# 2085161  68755  2018     2500         Englewood    NJ  YV4A22PL4J1212676
# 2085162  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 2085163  60240  2017     8342       San Leandro    CA  YV4A22NLXH1006162
#
#           Make         Model  final_tar  condition
# ...

# %%
df['Mileage'].mean()
# Out:
# 52663.88357990067

# %%
def fun(x):
    if x> 0 and x <= 25000:
        return 1
    elif x >25000 and x <= 52663.88357990067:
        return 2
    elif x >52663.88357990067 and x <= 75000:
        return 3
    elif x>75000:
        return 4
    
    
Mileage = df.Mileage.apply(fun)

# %%
Mileage
# Out:
# 0          2
# 1          1
# 2          2
# 3          2
# 4          1
#           ..
# 2085159    1
# 2085160    1
# 2085161    1
# 2085162    1
# 2085163    1
# Name: Mileage, Length: 2085164, dtype: int64

# %%
df['final_tar'] = Mileage

# %%
df    #554940+766896+270915+492413
# Out:
#          Price  Year  Mileage              City State                Vin  \
# 0         8995  2014    35725           El Paso    TX  19VDE2E53EE000083
# 1        10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 2         8995  2013    48851           El Paso    TX  19VDE2E52DE000025
# 3        10999  2014    39922           Windsor    CO  19VDE1F71EE003817
# 4        14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# ...        ...   ...      ...               ...   ...                ...
# 2085159  79900  2017       25      East Hanover    NJ  YV4BC0ZX0H1128239
# 2085160  80895  2017       10      Corte Madera    CA  YV4BC0ZX0H1124188
# 2085161  68755  2018     2500         Englewood    NJ  YV4A22PL4J1212676
# 2085162  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 2085163  60240  2017     8342       San Leandro    CA  YV4A22NLXH1006162
#
#           Make         Model  final_tar  condition
# ...

# %%
conditions = [
    (df['final_tar'] == 1) & (df['Year'] >2017),
    (df['final_tar'] == 1) & (df['Year'] <= 2017),
    (df['final_tar'] == 2) & (df['Year'] >2017),
    (df['final_tar'] == 2) & (df['Year'] <=2017),
    (df['final_tar'] == 3) & (df['Year'] >2017),
    (df['final_tar'] == 3) & (df['Year'] <= 2017),
    (df['final_tar'] == 4) & (df['Year'] >2017),
    (df['final_tar'] == 4) & (df['Year'] <=2017)
    ]

values = [1, 2, 3, 4, 5, 6, 7, 8]
df['condition'] = np.select(conditions, values)
df['condition']
# Out:
# 0          4
# 1          2
# 2          4
# 3          4
# 4          2
#           ..
# 2085159    2
# 2085160    2
# 2085161    1
# 2085162    2
# 2085163    2
# Name: condition, Length: 2085164, dtype: int32

# %%
df
# Out:
#          Price  Year  Mileage              City State                Vin  \
# 0         8995  2014    35725           El Paso    TX  19VDE2E53EE000083
# 1        10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 2         8995  2013    48851           El Paso    TX  19VDE2E52DE000025
# 3        10999  2014    39922           Windsor    CO  19VDE1F71EE003817
# 4        14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# ...        ...   ...      ...               ...   ...                ...
# 2085159  79900  2017       25      East Hanover    NJ  YV4BC0ZX0H1128239
# 2085160  80895  2017       10      Corte Madera    CA  YV4BC0ZX0H1124188
# 2085161  68755  2018     2500         Englewood    NJ  YV4A22PL4J1212676
# 2085162  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 2085163  60240  2017     8342       San Leandro    CA  YV4A22NLXH1006162
#
#           Make         Model  final_tar  condition
# ...

# %%
df1 = df[df['condition']== 1]
df2 = df[df['condition'] == 2]
df3 = df[df['condition'] == 3]
df4 = df[df['condition'] == 4]
df5 = df[df['condition'] == 5]
df6 = df[df['condition'] == 6]
df7 = df[df['condition'] == 7]
df8 = df[df['condition'] == 8]

# %%
df1['condition'] = df1['Price']-(df1['Price']*.2)
df2['condition'] = df2['Price']-(df2['Price']*.3)
df4['condition'] = df4['Price']-(df4['Price']*.35)
df6['condition'] = df6['Price']-(df6['Price']*.4)
df8['condition'] = df8['Price']-(df8['Price']*.5)
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6284/193936588.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['condition'] = df1['Price']-(df1['Price']*.2)
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6284/193936588.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['condition'] = df2['Price']-(df2['Price']*.3)
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6284/193936588.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df1
# Out:
#          Price  Year  Mileage               City State                Vin  \
# 6129     35721  2018        5          Littleton    CO  5J8TB4H37JL004139
# 6257     36000  2018        5          Littleton    CO  5J8TB4H37JL005209
# 6258     36000  2018        5          Littleton    CO  5J8TB4H34JL003045
# 6529     32995  2018      250           Cerritos    CA  19UUB1F30JA004453
# 6640     33929  2018      239    Hoffman Estates    IL  19UUB1F55JA000321
# ...        ...   ...      ...                ...   ...                ...
# 2085122  66240  2018       14           Nazareth    PA  LVY992ML7JP006733
# 2085133  55140  2018       15          Englewood    NJ  YV4A22RK6J1004304
# 2085135  56560  2018      230  Hasbrouck Heights    NJ  YV4A22RL6J1004070
# 2085149  59005  2018        8        San Leandro    CA  YV4A22RL6J1013609
# 2085161  68755  2018     2500          Englewood    NJ  YV4A22PL4J1212676
#
#           Make   Model  final_tar  condition
# ...

# %%
df2
# Out:
#          Price  Year  Mileage              City State                Vin  \
# 1        10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 4        14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# 13       17628  2015    13797             Fargo    ND  19VDE1F38FE001240
# 15       14995  2014    23454      Hackettstown    NJ  19VDE1F31EE009243
# 16       14990  2015    23603          Freeport    NY  19VDE1F3XFE007606
# ...        ...   ...      ...               ...   ...                ...
# 2085158  52995  2017     2474            Berwyn    PA  YV1A22MK1H1010445
# 2085159  79900  2017       25      East Hanover    NJ  YV4BC0ZX0H1128239
# 2085160  80895  2017       10      Corte Madera    CA  YV4BC0ZX0H1124188
# 2085162  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 2085163  60240  2017     8342       San Leandro    CA  YV4A22NLXH1006162
#
#           Make         Model  final_tar  condition
# ...

# %%
df3
# Out:
# Empty DataFrame
# Columns: [Price, Year, Mileage, City, State, Vin, Make, Model, final_tar, condition]
# Index: []

# %%
df4
# Out:
#          Price  Year  Mileage         City State                Vin   Make  \
# 0         8995  2014    35725      El Paso    TX  19VDE2E53EE000083  Acura
# 2         8995  2013    48851      El Paso    TX  19VDE2E52DE000025  Acura
# 3        10999  2014    39922      Windsor    CO  19VDE1F71EE003817  Acura
# 6        14490  2014    34032    Greatneck    NY  JH4CU2F84EC002686  Acura
# 7        13995  2013    32384  West Jordan    UT  JH4CU2F64DC006203  Acura
# ...        ...   ...      ...          ...   ...                ...    ...
# 2085092  35995  2015    39860       Berwyn    PA  YV4902RG8F2587612  Volvo
# 2085093  47995  2016    28647  Culver City    CA  YV4102XM5G1056400  Volvo
# 2085105  48995  2016    30799       Berwyn    PA  YV4A22PK2G1021841  Volvo
# 2085113  53775  2016    34906     Nazareth    PA  YV4A22PM4G1038044  Volvo
# 2085126  52700  2016    25658     Portland    OR  YV4A22PK6G1092153  Volvo
#
#               Model  final_tar  condition
# ...

# %%
df5  #drop outliers
# Out:
#         Price  Year  Mileage      City State                Vin       Make  \
# 129795  29867  2018    57872  Surprise    AZ  2GNAXMEV4J6103708  Chevrolet
# 966738  29867  2018    57872  Surprise    AZ  2GNAXMEV4J6103708  Chevrolet
#
#              Model  final_tar  condition
# 129795  EquinoxFWD          3          5
# 966738  EquinoxFWD          3          5

# %%
df6
# Out:
#          Price  Year  Mileage            City State                Vin   Make  \
# 8        10495  2013    57596       Waterbury    CT  19VDE2E50DE000234  Acura
# 9         9995  2013    63887         El Paso    TX  19VDE1F50DE010450  Acura
# 10       12921  2012    58550           Boise    ID  JH4CU2F44CC003220  Acura
# 18        9500  2011    68289         Arcadia    FL  JH4CU2F62BC007928  Acura
# 19        7990  2007    60552        Fairlawn    NJ  JH4CL96857C019060  Acura
# ...        ...   ...      ...             ...   ...                ...    ...
# 2084613  25441  2014    53609         Hamburg    PA  YV4902DZ9E2514174  Volvo
# 2084627  25993  2015    58157  Sinking Spring    PA  YV4902RB8F2620998  Volvo
# 2084728  32998  2015    56069         Raleigh    NC  YV4902NK5F1212146  Volvo
# 2084771  29399  2013    68047          Renton    WA  YV4902DZ2D2385810  Volvo
# 2085102  43620  2015    53019          Berwyn    PA  YV4902RB3F2577204  Volvo
#
# ...

# %%
df7
# Out:
# Empty DataFrame
# Columns: [Price, Year, Mileage, City, State, Vin, Make, Model, final_tar, condition]
# Index: []

# %%
df8
# Out:
#          Price  Year  Mileage               City State                Vin  \
# 5         7989  2012   105246              Miami    FL  JH4CU2F83CC019895
# 12        7750  2009    91980        San Antonio    TX  JH4CU26639C015787
# 54       11888  2012    84126           Manassas    VA  JH4CU2F43CC016959
# 91       10990  2012    81301          Homestead    FL  JH4CU2F80CC018400
# 111      11585  2012    80359              Davie    FL  JH4CU2F81CC002691
# ...        ...   ...      ...                ...   ...                ...
# 2084798   4995  1997   156677               Reno    NV  YV1LS5729V1382231
# 2084842  13963  2013   217804          Cleveland    OH  YV4952DZ9D2365555
# 2084969   3111  2001   202691             Odessa    TX  YV1SW61R512089006
# 2085053   5995  2003   144538  Fort Walton Beach    FL  YV1SZ59H831096165
# 2085107  34988  2017   188968          Santa Ana    CA  YV440MRU2H2142166
#
#           Make         Model  final_tar  condition
# ...

# %%
492413+270913+766896+552403+2537
# Out:
# 2085162

# %%
final_df = pd.concat([df1,df2,df4,df6,df8],ignore_index = True)

# %%
final_df
# Out:
#          Price  Year  Mileage               City State                Vin  \
# 0        35721  2018        5          Littleton    CO  5J8TB4H37JL004139
# 1        36000  2018        5          Littleton    CO  5J8TB4H37JL005209
# 2        36000  2018        5          Littleton    CO  5J8TB4H34JL003045
# 3        32995  2018      250           Cerritos    CA  19UUB1F30JA004453
# 4        33929  2018      239    Hoffman Estates    IL  19UUB1F55JA000321
# ...        ...   ...      ...                ...   ...                ...
# 2085157   4995  1997   156677               Reno    NV  YV1LS5729V1382231
# 2085158  13963  2013   217804          Cleveland    OH  YV4952DZ9D2365555
# 2085159   3111  2001   202691             Odessa    TX  YV1SW61R512089006
# 2085160   5995  2003   144538  Fort Walton Beach    FL  YV1SZ59H831096165
# 2085161  34988  2017   188968          Santa Ana    CA  YV440MRU2H2142166
#
#           Make     Model  final_tar  condition
# ...
